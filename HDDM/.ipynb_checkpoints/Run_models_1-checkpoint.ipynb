# %% [markdown]
# ## Note:
# This script is for parallel processing the HDDM processing for '1a', '1b', '1c', '2', and '6a', which share the same experimental design.

# %%
import sys
import hddm, IPython
print('Notebook is running:', sys.executable)
from platform import python_version # further check your python version
print('The current HDDM version is', python_version())
print('The current HDDM version is', hddm.__version__) # 0.8.0
print('The current IPython version is', IPython.__version__)
# Out:
# Notebook is running: /home/hcp4715/miniconda3/envs/hddm/bin/python
# The current HDDM version is 3.7.7
# The current HDDM version is 0.8.0
# The current IPython version is 7.13.0
# /home/hcp4715/miniconda3/envs/hddm/lib/python3.7/site-packages/IPython/parallel.py:13: ShimWarning: The `IPython.parallel` package has been deprecated since IPython 4.0. You should import from ipyparallel instead.
#   "You should import from ipyparallel instead.", ShimWarning)

# %%
# %matplotlib inline

# Preparation
import os, hddm, time, csv
import kabuki
from kabuki.analyze import gelman_rubin

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from datetime import date
import random

# %%
# define a function to run model in parallel for experiments share the same design
def run_model_1a(id):
    import hddm
    
    exp_name = '1a'
    print('running models %i'%id, 'for for exp', exp_name)
    dbname = 'df' + exp_name + '_chain_vtaz_%i.db'%id   # define the database name, which uses pickle format
    mname  = 'df' + exp_name + '_chain__vtaz_%i'%id     # define the name for the model
    fname  = 'df' + exp_name + '.v.hddm_stim.csv'
    df = hddm.load_csv(fname)
    m = hddm.HDDMStimCoding(df, 
                            include='z', 
                            stim_col='stim', 
                            depends_on={'v':['match','val'], 't':['match','val'],'a':['match','val']},
                            split_param='v', 
                            drift_criterion=False,
                            p_outlier=0.05)
    m.find_starting_values()
    m.sample(10000, burn=5000, thin=5, dbname=dbname, db='pickle')
    m.save(mname) # save the model
    return m

def run_model_1b(id):
    import hddm
    
    exp_name = '1b'
    print('running models %i'%id, 'for for exp', exp_name)
    dbname = 'df' + exp_name + '_chain_vtaz_%i.db'%id   # define the database name, which uses pickle format
    mname  = 'df' + exp_name + '_chain__vtaz_%i'%id     # define the name for the model
    fname  = 'df' + exp_name + '.v.hddm_stim.csv'
    df = hddm.load_csv(fname)
    m = hddm.HDDMStimCoding(df, 
                            include='z', 
                            stim_col='stim', 
                            depends_on={'v':['match','val'], 't':['match','val'],'a':['match','val']},
                            split_param='v', 
                            drift_criterion=False,
                            p_outlier=0.05)
    m.find_starting_values()
    m.sample(10000, burn=5000, thin=5, dbname=dbname, db='pickle')
    m.save(mname) # save the model
    return m

def run_model_1c(id):
    import hddm
    
    exp_name = '1c'
    print('running models %i'%id, 'for for exp', exp_name)
    dbname = 'df' + exp_name + '_chain_vtaz_%i.db'%id   # define the database name, which uses pickle format
    mname  = 'df' + exp_name + '_chain__vtaz_%i'%id     # define the name for the model
    fname  = 'df' + exp_name + '.v.hddm_stim.csv'
    df = hddm.load_csv(fname)
    m = hddm.HDDMStimCoding(df, 
                            include='z', 
                            stim_col='stim', 
                            depends_on={'v':['match','val'], 't':['match','val'],'a':['match','val']},
                            split_param='v', 
                            drift_criterion=False,
                            p_outlier=0.05)
    m.find_starting_values()
    m.sample(10000, burn=5000, thin=5, dbname=dbname, db='pickle')
    m.save(mname) # save the model
    return m

# define a function to run model in parallel for experiment 1b
def run_model_2(id):
    import hddm
    
    exp_name = '2'
    print('running models %i'%id, 'for for exp', exp_name)
    dbname = 'df' + exp_name + '_chain_vtaz_%i.db'%id   # define the database name, which uses pickle format
    mname  = 'df' + exp_name + '_chain__vtaz_%i'%id     # define the name for the model
    fname  = 'df' + exp_name + '.v.hddm_stim.csv'
    df = hddm.load_csv(fname)
    m = hddm.HDDMStimCoding(df, 
                            include='z', 
                            stim_col='stim', 
                            depends_on={'v':['match','val'], 't':['match','val'],'a':['match','val']},
                            split_param='v', 
                            drift_criterion=False,
                            p_outlier=0.05)
    m.find_starting_values()
    m.sample(10000, burn=5000, thin=5, dbname=dbname, db='pickle')
    m.save(mname) # save the model
    return m

def run_model_6a(id):
    import hddm
    
    exp_name = '6a'
    print('running models %i'%id, 'for for exp', exp_name)
    dbname = 'df' + exp_name + '_chain_vtaz_%i.db'%id   # define the database name, which uses pickle format
    mname  = 'df' + exp_name + '_chain__vtaz_%i'%id     # define the name for the model
    fname  = 'df' + exp_name + '.v.hddm_stim.csv'
    df = hddm.load_csv(fname)
    m = hddm.HDDMStimCoding(df, 
                            include='z', 
                            stim_col='stim', 
                            depends_on={'v':['match','val'], 't':['match','val'],'a':['match','val']},
                            split_param='v', 
                            drift_criterion=False,
                            p_outlier=0.05)
    m.find_starting_values()
    m.sample(10000, burn=5000, thin=5, dbname=dbname, db='pickle')
    m.save(mname) # save the model
    return m

# %%
# exp_list = ['1a', '1b', '1c', '2', '6a']
exp_list = ['1a', '1b', '1c']
for mm in range(len(exp_list)):
    
    
    if exp_list[mm] == '1a': 
        start_time = time.time()   # the start time of the processing#
        print('\nrun model for exp', exp_list[mm])
        from ipyparallel import Client
        rc = Client()
        jobs = rc[4:8].map(run_model_1a, range(4)) # 4 is the number of chains
        df_models = jobs.get()
        print("Running 4 chains for exp", exp_list[mm], "used: %f seconds." % (time.time() - start_time))
        
    elif exp_list[mm] == '1b':
        start_time = time.time()   # the start time of the processing#
        print('\nrun model for exp', exp_list[mm])
        from ipyparallel import Client
        rc = Client()
        jobs = rc[4:8].map(run_model_1b, range(4)) # 4 is the number of chains
        df_models = jobs.get()
        print("Running 4 chains for exp", exp_list[mm], "used: %f seconds." % (time.time() - start_time))
        
    elif exp_list[mm] == '1c':
        start_time = time.time()   # the start time of the processing#
        print('\nrun model for exp', exp_list[mm])
        from ipyparallel import Client
        rc = Client()
        jobs = rc[4:8].map(run_model_1c, range(4)) # 4 is the number of chains
        df_models = jobs.get()
        print("Running 4 chains for exp", exp_list[mm], "used: %f seconds." % (time.time() - start_time))
# Out:
# run model for exp 1a
# Running 4 chains for exp 1a used: 25711.408953 seconds.
#
# run model for exp 1b
# Running 4 chains for exp 1b used: 26624.204552 seconds.
#
# run model for exp 1c
# Running 4 chains for exp 1c used: 11342.836805 seconds.

# %%
gelman_rubin(df_models)
# Out:
# {'a(Match.Bad)': 1.0005572708625463,
#  'a(Match.Good)': 1.0005371625122395,
#  'a(Match.Neutral)': 1.0333170101117481,
#  'a(Mismatch.Bad)': 1.000289690497579,
#  'a(Mismatch.Good)': 1.0006208081794707,
#  'a(Mismatch.Neutral)': 1.0016289948313746,
#  'a_std': 1.0196730412076918,
#  'a_subj(Match.Bad).1215': 0.99963300826818,
#  'a_subj(Match.Good).1215': 1.0002900085236002,
#  'a_subj(Match.Neutral).1215': 1.0001156100462698,
#  'a_subj(Match.Bad).1216': 1.0016492821353016,
#  'a_subj(Match.Good).1216': 1.0018406965017423,
#  'a_subj(Match.Neutral).1216': 1.0031429656394635,
#  'a_subj(Match.Bad).1217': 0.999687545140149,
#  'a_subj(Match.Good).1217': 1.0003152961353579,
#  'a_subj(Match.Neutral).1217': 1.0004039326875251,
#  'a_subj(Match.Bad).1218': 1.0009018983620015,
#  'a_subj(Match.Good).1218': 0.9996470324710969,
#  'a_subj(Match.Neutral).1218': 1.001449588837532,
#  'a_subj(Match.Bad).1219': 0.9998901252157019,
#  'a_subj(Match.Good).1219': 1.0037397612658887,
#  'a_subj(Match.Neutral).1219': 1.0069067141384187,
#  'a_subj(Match.Bad).1220': 1.0000279775552925,
#  'a_subj(Match.Good).1220': 1.0009965555290417,
#  'a_subj(Match.Neutral).1220': 1.0001238892001738,
#  'a_subj(Match.Bad).1221': 0.9998363258670879,
#  'a_subj(Match.Good).1221': 1.0000306194226856,
#  'a_subj(Match.Neutral).1221': 1.0026061093026328,
#  'a_subj(Match.Bad).1222': 1.0014200464989544,
#  'a_subj(Match.Good).1222': 1.0010824506805722,
#  'a_subj(Match.Neutral).1222': 1.0013423134060957,
#  'a_subj(Match.Bad).1223': 1.0000085777551546,
#  'a_subj(Match.Good).1223': 1.0020326011850398,
#  'a_subj(Match.Neutral).1223': 1.0047890948970866,
#  'a_subj(Match.Bad).1224': 0.9995981504799244,
#  'a_subj(Match.Good).1224': 1.000546293158778,
#  'a_subj(Match.Neutral).1224': 1.0023246977924092,
#  'a_subj(Match.Bad).1225': 1.0014353938658171,
#  'a_subj(Match.Good).1225': 0.9999529541651913,
#  'a_subj(Match.Neutral).1225': 0.9998888647448071,
#  'a_subj(Match.Bad).1226': 1.0023378308058224,
#  'a_subj(Match.Good).1226': 0.9999651228585162,
#  'a_subj(Match.Neutral).1226': 1.0027782930582223,
#  'a_subj(Match.Bad).1227': 1.0009148898855391,
#  'a_subj(Match.Good).1227': 1.0013850070876456,
#  'a_subj(Match.Neutral).1227': 1.0000610857002559,
#  'a_subj(Match.Bad).1228': 1.0023610848479048,
#  'a_subj(Match.Good).1228': 1.0020609928141957,
#  'a_subj(Match.Neutral).1228': 0.9996336665687191,
#  'a_subj(Match.Bad).1229': 1.0001842842585182,
#  'a_subj(Match.Good).1229': 0.9999921659962933,
#  'a_subj(Match.Neutral).1229': 1.0011177226179677,
#  'a_subj(Match.Bad).1230': 1.0006622885110887,
#  'a_subj(Match.Good).1230': 0.9997871251079313,
#  'a_subj(Match.Neutral).1230': 1.0003500547241233,
#  'a_subj(Match.Bad).1231': 0.9997302790896987,
#  'a_subj(Match.Good).1231': 1.0006060982892424,
#  'a_subj(Match.Neutral).1231': 1.0009619985915528,
#  'a_subj(Match.Bad).1232': 1.0011570020442717,
#  'a_subj(Match.Good).1232': 0.9997238779963711,
#  'a_subj(Match.Neutral).1232': 1.0130054837289808,
#  'a_subj(Match.Bad).1233': 0.9999950173533062,
#  'a_subj(Match.Good).1233': 1.0003040606532099,
#  'a_subj(Match.Neutral).1233': 1.000090616832954,
#  'a_subj(Match.Bad).1234': 1.001047186382938,
#  'a_subj(Match.Good).1234': 1.000474605816293,
#  'a_subj(Match.Neutral).1234': 1.0010783331761588,
#  'a_subj(Match.Bad).1235': 1.0024565593503867,
#  'a_subj(Match.Good).1235': 1.000854361242928,
#  'a_subj(Match.Neutral).1235': 1.0008858853933909,
#  'a_subj(Match.Bad).1236': 1.0000647404087788,
#  'a_subj(Match.Good).1236': 1.0010420122597952,
#  'a_subj(Match.Neutral).1236': 1.0155585842632389,
#  'a_subj(Match.Bad).1237': 1.0012538348940259,
#  'a_subj(Match.Good).1237': 0.9997124565518939,
#  'a_subj(Match.Neutral).1237': 1.5233376914967118,
#  'a_subj(Mismatch.Bad).1215': 0.9999283303007643,
#  'a_subj(Mismatch.Good).1215': 0.9998163040007263,
#  'a_subj(Mismatch.Neutral).1215': 0.9995966040111084,
#  'a_subj(Mismatch.Bad).1216': 1.0022466661759564,
#  'a_subj(Mismatch.Good).1216': 0.999590487153424,
#  'a_subj(Mismatch.Neutral).1216': 1.0050906468280452,
#  'a_subj(Mismatch.Bad).1217': 1.0003185254465166,
#  'a_subj(Mismatch.Good).1217': 0.999956911453689,
#  'a_subj(Mismatch.Neutral).1217': 1.009383068447159,
#  'a_subj(Mismatch.Bad).1218': 0.9998320968995565,
#  'a_subj(Mismatch.Good).1218': 0.9997352636930362,
#  'a_subj(Mismatch.Neutral).1218': 1.000436167611327,
#  'a_subj(Mismatch.Bad).1219': 0.9996880932477417,
#  'a_subj(Mismatch.Good).1219': 1.0040846689141105,
#  'a_subj(Mismatch.Neutral).1219': 1.0001223855711485,
#  'a_subj(Mismatch.Bad).1220': 1.0004321281917203,
#  'a_subj(Mismatch.Good).1220': 0.9998555538504607,
#  'a_subj(Mismatch.Neutral).1220': 1.0018953440276681,
#  'a_subj(Mismatch.Bad).1221': 1.001714084480354,
#  'a_subj(Mismatch.Good).1221': 1.0006515670070024,
#  'a_subj(Mismatch.Neutral).1221': 1.0001234325776074,
#  'a_subj(Mismatch.Bad).1222': 1.0021300447767676,
#  'a_subj(Mismatch.Good).1222': 0.9997514704642978,
#  'a_subj(Mismatch.Neutral).1222': 1.0004295665579188,
#  'a_subj(Mismatch.Bad).1223': 1.0004167367307397,
#  'a_subj(Mismatch.Good).1223': 1.000155323516562,
#  'a_subj(Mismatch.Neutral).1223': 1.0025412242750211,
#  'a_subj(Mismatch.Bad).1224': 0.9996701659586846,
#  'a_subj(Mismatch.Good).1224': 1.0022833413358174,
#  'a_subj(Mismatch.Neutral).1224': 1.0000195467568804,
#  'a_subj(Mismatch.Bad).1225': 1.00115116842251,
#  'a_subj(Mismatch.Good).1225': 1.0001837879759996,
#  'a_subj(Mismatch.Neutral).1225': 0.9998502199156996,
#  'a_subj(Mismatch.Bad).1226': 1.0031935234643892,
#  'a_subj(Mismatch.Good).1226': 0.9999190487742168,
#  'a_subj(Mismatch.Neutral).1226': 0.9998535530161766,
#  'a_subj(Mismatch.Bad).1227': 0.999805684830722,
#  'a_subj(Mismatch.Good).1227': 1.0001118444119657,
#  'a_subj(Mismatch.Neutral).1227': 0.9999693525719928,
#  'a_subj(Mismatch.Bad).1228': 0.9998919431908532,
#  'a_subj(Mismatch.Good).1228': 0.9995183876877041,
#  'a_subj(Mismatch.Neutral).1228': 1.0011900364418116,
#  'a_subj(Mismatch.Bad).1229': 1.0009484112297062,
#  'a_subj(Mismatch.Good).1229': 1.0003412341915467,
#  'a_subj(Mismatch.Neutral).1229': 1.0012214197649878,
#  'a_subj(Mismatch.Bad).1230': 1.0003836084236162,
#  'a_subj(Mismatch.Good).1230': 1.0019857884489667,
#  'a_subj(Mismatch.Neutral).1230': 1.0000579477545524,
#  'a_subj(Mismatch.Bad).1231': 1.0005543826766494,
#  'a_subj(Mismatch.Good).1231': 1.000569481385952,
#  'a_subj(Mismatch.Neutral).1231': 1.0002904366011358,
#  'a_subj(Mismatch.Bad).1232': 1.000968430405048,
#  'a_subj(Mismatch.Good).1232': 1.0005066805210545,
#  'a_subj(Mismatch.Neutral).1232': 1.0016316029666594,
#  'a_subj(Mismatch.Bad).1233': 1.0000757700823277,
#  'a_subj(Mismatch.Good).1233': 0.9999815123348659,
#  'a_subj(Mismatch.Neutral).1233': 1.0007864082828792,
#  'a_subj(Mismatch.Bad).1234': 1.0000003571231375,
#  'a_subj(Mismatch.Good).1234': 1.000030372990994,
#  'a_subj(Mismatch.Neutral).1234': 1.0011719875226912,
#  'a_subj(Mismatch.Bad).1235': 0.9998055673457448,
#  'a_subj(Mismatch.Good).1235': 1.000164625889833,
#  'a_subj(Mismatch.Neutral).1235': 0.9996877296356576,
#  'a_subj(Mismatch.Bad).1236': 1.0004787913487998,
#  'a_subj(Mismatch.Good).1236': 1.0008026601730662,
#  'a_subj(Mismatch.Neutral).1236': 1.000186384890303,
#  'a_subj(Mismatch.Bad).1237': 1.0004928756387585,
#  'a_subj(Mismatch.Good).1237': 0.9997392433394611,
#  'a_subj(Mismatch.Neutral).1237': 0.9999746481654342,
#  'v(Match.Bad)': 1.0000622548101512,
#  'v(Match.Good)': 1.00013383990546,
#  'v(Match.Neutral)': 1.0022019211788211,
#  'v(Mismatch.Bad)': 1.0007068141072415,
#  'v(Mismatch.Good)': 1.0009605090594682,
#  'v(Mismatch.Neutral)': 1.0005198527099244,
#  'v_std': 1.0031038729913522,
#  'v_subj(Match.Bad).1215': 1.001432602449818,
#  'v_subj(Match.Good).1215': 1.0001501481562045,
#  'v_subj(Match.Neutral).1215': 1.0001071192017728,
#  'v_subj(Match.Bad).1216': 1.000205242589575,
#  'v_subj(Match.Good).1216': 1.0016486384580114,
#  'v_subj(Match.Neutral).1216': 0.9996076824353873,
#  'v_subj(Match.Bad).1217': 1.0006601205192274,
#  'v_subj(Match.Good).1217': 1.0002278418738741,
#  'v_subj(Match.Neutral).1217': 1.001501624468578,
#  'v_subj(Match.Bad).1218': 1.0004707467187317,
#  'v_subj(Match.Good).1218': 1.0004030245179485,
#  'v_subj(Match.Neutral).1218': 0.9999807666021616,
#  'v_subj(Match.Bad).1219': 1.0002975347671395,
#  'v_subj(Match.Good).1219': 0.999804177054127,
#  'v_subj(Match.Neutral).1219': 1.0018944143549338,
#  'v_subj(Match.Bad).1220': 1.0006249166731067,
#  'v_subj(Match.Good).1220': 1.000353701296591,
#  'v_subj(Match.Neutral).1220': 0.9999680662712125,
#  'v_subj(Match.Bad).1221': 0.9998873782061739,
#  'v_subj(Match.Good).1221': 0.9995737287905294,
#  'v_subj(Match.Neutral).1221': 0.9996376258520525,
#  'v_subj(Match.Bad).1222': 0.999843485162448,
#  'v_subj(Match.Good).1222': 1.0013286769921403,
#  'v_subj(Match.Neutral).1222': 1.000423843322611,
#  'v_subj(Match.Bad).1223': 1.0001501590129922,
#  'v_subj(Match.Good).1223': 1.0007008301658005,
#  'v_subj(Match.Neutral).1223': 0.9995683221197984,
#  'v_subj(Match.Bad).1224': 0.9997455257279867,
#  'v_subj(Match.Good).1224': 1.0014586592038581,
#  'v_subj(Match.Neutral).1224': 0.9999970755516375,
#  'v_subj(Match.Bad).1225': 1.000490353013511,
#  'v_subj(Match.Good).1225': 0.9999350277673233,
#  'v_subj(Match.Neutral).1225': 1.0003962202321637,
#  'v_subj(Match.Bad).1226': 1.0008971981490697,
#  'v_subj(Match.Good).1226': 0.999879916914514,
#  'v_subj(Match.Neutral).1226': 1.000497107927345,
#  'v_subj(Match.Bad).1227': 1.0005385556907438,
#  'v_subj(Match.Good).1227': 1.000451390906929,
#  'v_subj(Match.Neutral).1227': 0.9997449253656836,
#  'v_subj(Match.Bad).1228': 0.9999639274899402,
#  'v_subj(Match.Good).1228': 1.0008050424909418,
#  'v_subj(Match.Neutral).1228': 1.0003446684791106,
#  'v_subj(Match.Bad).1229': 0.9999914387178247,
#  'v_subj(Match.Good).1229': 0.9995447098369609,
#  'v_subj(Match.Neutral).1229': 0.9996290902504649,
#  'v_subj(Match.Bad).1230': 0.9999018143110527,
#  'v_subj(Match.Good).1230': 1.0001754676952235,
#  'v_subj(Match.Neutral).1230': 0.9999429144642414,
#  'v_subj(Match.Bad).1231': 1.0012204719403877,
#  'v_subj(Match.Good).1231': 1.0013456718326055,
#  'v_subj(Match.Neutral).1231': 0.9998316617064021,
#  'v_subj(Match.Bad).1232': 0.999621618928484,
#  'v_subj(Match.Good).1232': 1.0001287798647536,
#  'v_subj(Match.Neutral).1232': 1.000305453867959,
#  'v_subj(Match.Bad).1233': 0.9998885690301225,
#  'v_subj(Match.Good).1233': 1.000189150494494,
#  'v_subj(Match.Neutral).1233': 1.000252559981437,
#  'v_subj(Match.Bad).1234': 1.0001874386081298,
#  'v_subj(Match.Good).1234': 1.0001561707768183,
#  'v_subj(Match.Neutral).1234': 1.0001790945684166,
#  'v_subj(Match.Bad).1235': 0.9998129542731506,
#  'v_subj(Match.Good).1235': 1.0008477883266513,
#  'v_subj(Match.Neutral).1235': 0.9997216892423477,
#  'v_subj(Match.Bad).1236': 0.999720207947307,
#  'v_subj(Match.Good).1236': 0.9998341895228973,
#  'v_subj(Match.Neutral).1236': 1.0028114386589586,
#  'v_subj(Match.Bad).1237': 1.0007958048759786,
#  'v_subj(Match.Good).1237': 1.0003444190999726,
#  'v_subj(Match.Neutral).1237': 1.1520673499090122,
#  'v_subj(Mismatch.Bad).1215': 1.0002748323313717,
#  'v_subj(Mismatch.Good).1215': 1.0004794063020612,
#  'v_subj(Mismatch.Neutral).1215': 1.0007351510980935,
#  'v_subj(Mismatch.Bad).1216': 1.0009596870119388,
#  'v_subj(Mismatch.Good).1216': 0.99995386768076,
#  'v_subj(Mismatch.Neutral).1216': 1.0139224923014143,
#  'v_subj(Mismatch.Bad).1217': 0.9998000980698036,
#  'v_subj(Mismatch.Good).1217': 0.9998754547213942,
#  'v_subj(Mismatch.Neutral).1217': 1.0005872265431652,
#  'v_subj(Mismatch.Bad).1218': 1.0000778946547009,
#  'v_subj(Mismatch.Good).1218': 0.999831372191889,
#  'v_subj(Mismatch.Neutral).1218': 1.0002168667903892,
#  'v_subj(Mismatch.Bad).1219': 1.000407934855292,
#  'v_subj(Mismatch.Good).1219': 1.000342551698414,
#  'v_subj(Mismatch.Neutral).1219': 1.0007424067026958,
#  'v_subj(Mismatch.Bad).1220': 0.9998317647253739,
#  'v_subj(Mismatch.Good).1220': 0.9996813298386392,
#  'v_subj(Mismatch.Neutral).1220': 1.0001598974164367,
#  'v_subj(Mismatch.Bad).1221': 1.0005322661686977,
#  'v_subj(Mismatch.Good).1221': 0.9999061862563754,
#  'v_subj(Mismatch.Neutral).1221': 1.0003549648290535,
#  'v_subj(Mismatch.Bad).1222': 1.0046230120670534,
#  'v_subj(Mismatch.Good).1222': 1.0006794684708695,
#  'v_subj(Mismatch.Neutral).1222': 0.9996648396166385,
#  'v_subj(Mismatch.Bad).1223': 0.9999448416022355,
#  'v_subj(Mismatch.Good).1223': 0.9998644818448073,
#  'v_subj(Mismatch.Neutral).1223': 1.000627890485222,
#  'v_subj(Mismatch.Bad).1224': 0.9997344060274823,
#  'v_subj(Mismatch.Good).1224': 1.0001292240509116,
#  'v_subj(Mismatch.Neutral).1224': 1.0005719254259022,
#  'v_subj(Mismatch.Bad).1225': 1.000812839247962,
#  'v_subj(Mismatch.Good).1225': 0.9996428572107218,
#  'v_subj(Mismatch.Neutral).1225': 0.9997473432313444,
#  'v_subj(Mismatch.Bad).1226': 1.0008219739794886,
#  'v_subj(Mismatch.Good).1226': 0.9998413539589146,
#  'v_subj(Mismatch.Neutral).1226': 0.9999153348965192,
#  'v_subj(Mismatch.Bad).1227': 0.9997185162098102,
#  'v_subj(Mismatch.Good).1227': 1.0011740399957547,
#  'v_subj(Mismatch.Neutral).1227': 0.9999265065522758,
#  'v_subj(Mismatch.Bad).1228': 0.999578923645583,
#  'v_subj(Mismatch.Good).1228': 1.0002864410525882,
#  'v_subj(Mismatch.Neutral).1228': 1.0004690120505537,
#  'v_subj(Mismatch.Bad).1229': 0.9999952097289515,
#  'v_subj(Mismatch.Good).1229': 1.0003191025148221,
#  'v_subj(Mismatch.Neutral).1229': 1.0017879016574314,
#  'v_subj(Mismatch.Bad).1230': 0.9998140429980548,
#  'v_subj(Mismatch.Good).1230': 0.9998091320715142,
#  'v_subj(Mismatch.Neutral).1230': 1.000777653275351,
#  'v_subj(Mismatch.Bad).1231': 0.9996222988378936,
#  'v_subj(Mismatch.Good).1231': 1.0009454887622236,
#  'v_subj(Mismatch.Neutral).1231': 0.9996514826184115,
#  'v_subj(Mismatch.Bad).1232': 1.00140668679444,
#  'v_subj(Mismatch.Good).1232': 0.9999322597799124,
#  'v_subj(Mismatch.Neutral).1232': 1.0000711480483422,
#  'v_subj(Mismatch.Bad).1233': 0.9996448601673488,
#  'v_subj(Mismatch.Good).1233': 1.001458139110896,
#  'v_subj(Mismatch.Neutral).1233': 1.0002144912655708,
#  'v_subj(Mismatch.Bad).1234': 0.9995748281613722,
#  'v_subj(Mismatch.Good).1234': 0.9999193825383945,
#  'v_subj(Mismatch.Neutral).1234': 1.001448143047726,
#  'v_subj(Mismatch.Bad).1235': 1.000908776473582,
#  'v_subj(Mismatch.Good).1235': 1.0006012441269097,
#  'v_subj(Mismatch.Neutral).1235': 0.9997369597440042,
#  'v_subj(Mismatch.Bad).1236': 1.000231184863905,
#  'v_subj(Mismatch.Good).1236': 1.0003163641129775,
#  'v_subj(Mismatch.Neutral).1236': 1.0011061964334578,
#  'v_subj(Mismatch.Bad).1237': 0.9996794415678802,
#  'v_subj(Mismatch.Good).1237': 0.9995902743954076,
#  'v_subj(Mismatch.Neutral).1237': 1.0000209345025857,
#  't(Match.Bad)': 1.0010378163787024,
#  't(Match.Good)': 1.0004025163653323,
#  't(Match.Neutral)': 1.0205398677173292,
#  't(Mismatch.Bad)': 1.000339621808184,
#  't(Mismatch.Good)': 1.0006081338171977,
#  't(Mismatch.Neutral)': 0.9999992644680734,
#  't_std': 1.0000921988939326,
#  't_subj(Match.Bad).1215': 0.9997250052305248,
#  't_subj(Match.Good).1215': 1.0007513237011822,
#  't_subj(Match.Neutral).1215': 1.0001177816572429,
#  't_subj(Match.Bad).1216': 1.0009587767242532,
#  't_subj(Match.Good).1216': 1.0042125564425326,
#  't_subj(Match.Neutral).1216': 1.0000710498408212,
#  't_subj(Match.Bad).1217': 1.001044996659787,
#  't_subj(Match.Good).1217': 0.9997646097941232,
#  't_subj(Match.Neutral).1217': 1.0003141871109893,
#  't_subj(Match.Bad).1218': 0.9997359541459004,
#  't_subj(Match.Good).1218': 1.0000333420354677,
#  't_subj(Match.Neutral).1218': 1.0001847250266624,
#  't_subj(Match.Bad).1219': 1.0000206154207472,
#  't_subj(Match.Good).1219': 1.0020414382897467,
#  't_subj(Match.Neutral).1219': 1.0037766656636098,
#  't_subj(Match.Bad).1220': 0.9999619357787675,
#  't_subj(Match.Good).1220': 0.9997258570595902,
#  't_subj(Match.Neutral).1220': 0.9997813796101088,
#  't_subj(Match.Bad).1221': 0.9997320021443096,
#  't_subj(Match.Good).1221': 1.0000259618447378,
#  't_subj(Match.Neutral).1221': 1.000763954252421,
#  't_subj(Match.Bad).1222': 1.0001884671200036,
#  't_subj(Match.Good).1222': 1.0036146513296902,
#  't_subj(Match.Neutral).1222': 1.0004622996002017,
#  't_subj(Match.Bad).1223': 1.0001198163433371,
#  't_subj(Match.Good).1223': 1.0000559207294604,
#  't_subj(Match.Neutral).1223': 1.0005844772369346,
#  't_subj(Match.Bad).1224': 0.9999970583378179,
#  't_subj(Match.Good).1224': 1.0007436469497928,
#  't_subj(Match.Neutral).1224': 1.0013090156991886,
#  't_subj(Match.Bad).1225': 1.0002562506593298,
#  't_subj(Match.Good).1225': 1.0007934426165908,
#  't_subj(Match.Neutral).1225': 0.9999043484234145,
#  't_subj(Match.Bad).1226': 1.0040793191287218,
#  't_subj(Match.Good).1226': 1.000939621279404,
#  't_subj(Match.Neutral).1226': 1.0003183102587487,
#  't_subj(Match.Bad).1227': 1.000482869848556,
#  't_subj(Match.Good).1227': 1.0009958562371515,
#  't_subj(Match.Neutral).1227': 0.9995664317514859,
#  't_subj(Match.Bad).1228': 1.0026605663127077,
#  't_subj(Match.Good).1228': 1.0017978314152742,
#  't_subj(Match.Neutral).1228': 0.9997573425010541,
#  't_subj(Match.Bad).1229': 1.000172190355963,
#  't_subj(Match.Good).1229': 0.9998444768723664,
#  't_subj(Match.Neutral).1229': 1.0007189115469237,
#  't_subj(Match.Bad).1230': 1.0000618985596137,
#  't_subj(Match.Good).1230': 1.0000167454898738,
#  't_subj(Match.Neutral).1230': 1.000171190730385,
#  't_subj(Match.Bad).1231': 1.0000291866650404,
#  't_subj(Match.Good).1231': 1.0007215296614327,
#  't_subj(Match.Neutral).1231': 0.9999703021609387,
#  't_subj(Match.Bad).1232': 1.0018631226350683,
#  't_subj(Match.Good).1232': 1.0000382146236526,
#  't_subj(Match.Neutral).1232': 1.0167960925387451,
#  't_subj(Match.Bad).1233': 0.9995950378916175,
#  't_subj(Match.Good).1233': 0.9995349912456424,
#  't_subj(Match.Neutral).1233': 1.0010192881976299,
#  't_subj(Match.Bad).1234': 1.0043249672365009,
#  't_subj(Match.Good).1234': 0.9996376076754258,
#  't_subj(Match.Neutral).1234': 1.0003955314551867,
#  't_subj(Match.Bad).1235': 1.0002035718697155,
#  't_subj(Match.Good).1235': 1.0001839331285474,
#  't_subj(Match.Neutral).1235': 1.002538613888691,
#  't_subj(Match.Bad).1236': 1.0006070373133136,
#  't_subj(Match.Good).1236': 1.002002920193821,
#  't_subj(Match.Neutral).1236': 1.0376254117467973,
#  't_subj(Match.Bad).1237': 1.0001783187201774,
#  't_subj(Match.Good).1237': 0.9999008578410857,
#  't_subj(Match.Neutral).1237': 1.788729438819177,
#  't_subj(Mismatch.Bad).1215': 0.999609334423879,
#  't_subj(Mismatch.Good).1215': 0.999536752458652,
#  't_subj(Mismatch.Neutral).1215': 0.9997963229757879,
#  't_subj(Mismatch.Bad).1216': 1.0075561601225753,
#  't_subj(Mismatch.Good).1216': 1.0006895871428734,
#  't_subj(Mismatch.Neutral).1216': 1.0557021075712556,
#  't_subj(Mismatch.Bad).1217': 0.9998754853040756,
#  't_subj(Mismatch.Good).1217': 0.9998278407677333,
#  't_subj(Mismatch.Neutral).1217': 1.0150786883311087,
#  't_subj(Mismatch.Bad).1218': 1.0007204503311826,
#  't_subj(Mismatch.Good).1218': 1.0002198051003832,
#  't_subj(Mismatch.Neutral).1218': 1.0004537436562055,
#  't_subj(Mismatch.Bad).1219': 0.9996768987556135,
#  't_subj(Mismatch.Good).1219': 1.006462799217181,
#  't_subj(Mismatch.Neutral).1219': 0.9997266149049511,
#  't_subj(Mismatch.Bad).1220': 0.9998800042850169,
#  't_subj(Mismatch.Good).1220': 1.0000355104719623,
#  't_subj(Mismatch.Neutral).1220': 1.0016920110176313,
#  't_subj(Mismatch.Bad).1221': 0.9998741424526073,
#  't_subj(Mismatch.Good).1221': 0.9995386510912339,
#  't_subj(Mismatch.Neutral).1221': 1.0001263603668382,
#  't_subj(Mismatch.Bad).1222': 1.0005850084281263,
#  't_subj(Mismatch.Good).1222': 1.0001948118004007,
#  't_subj(Mismatch.Neutral).1222': 1.0005572596011407,
#  't_subj(Mismatch.Bad).1223': 1.0002036791047548,
#  't_subj(Mismatch.Good).1223': 0.9997792876080451,
#  't_subj(Mismatch.Neutral).1223': 1.0002000253415462,
#  't_subj(Mismatch.Bad).1224': 0.9999918807149507,
#  't_subj(Mismatch.Good).1224': 1.0005002678943091,
#  't_subj(Mismatch.Neutral).1224': 1.000686087341092,
#  't_subj(Mismatch.Bad).1225': 1.0012905565959092,
#  't_subj(Mismatch.Good).1225': 1.00052984981681,
#  't_subj(Mismatch.Neutral).1225': 0.9997147968733959,
#  't_subj(Mismatch.Bad).1226': 1.0068873045222297,
#  't_subj(Mismatch.Good).1226': 1.000073723264551,
#  't_subj(Mismatch.Neutral).1226': 1.0000452808445504,
#  't_subj(Mismatch.Bad).1227': 0.9997867159967039,
#  't_subj(Mismatch.Good).1227': 1.0009576661256445,
#  't_subj(Mismatch.Neutral).1227': 1.0003370397065066,
#  't_subj(Mismatch.Bad).1228': 1.0002264323644834,
#  't_subj(Mismatch.Good).1228': 0.9997711912973705,
#  't_subj(Mismatch.Neutral).1228': 0.9995216752893504,
#  't_subj(Mismatch.Bad).1229': 1.0009556367795833,
#  't_subj(Mismatch.Good).1229': 1.0009582048556958,
#  't_subj(Mismatch.Neutral).1229': 0.9997133077908334,
#  't_subj(Mismatch.Bad).1230': 1.000321093470089,
#  't_subj(Mismatch.Good).1230': 1.0014345278420465,
#  't_subj(Mismatch.Neutral).1230': 1.0009815451111366,
#  't_subj(Mismatch.Bad).1231': 1.0000067036518925,
#  't_subj(Mismatch.Good).1231': 0.9997098239190845,
#  't_subj(Mismatch.Neutral).1231': 0.9995970843149634,
#  't_subj(Mismatch.Bad).1232': 1.0006413628345006,
#  't_subj(Mismatch.Good).1232': 1.0006716166891034,
#  't_subj(Mismatch.Neutral).1232': 1.000901976090321,
#  't_subj(Mismatch.Bad).1233': 0.999792022527123,
#  't_subj(Mismatch.Good).1233': 1.0004055623030066,
#  't_subj(Mismatch.Neutral).1233': 1.0017386298846793,
#  't_subj(Mismatch.Bad).1234': 0.9996940396410148,
#  't_subj(Mismatch.Good).1234': 1.0005084957336325,
#  't_subj(Mismatch.Neutral).1234': 1.0005677908450454,
#  't_subj(Mismatch.Bad).1235': 1.0002812408885635,
#  't_subj(Mismatch.Good).1235': 0.9997770847280126,
#  't_subj(Mismatch.Neutral).1235': 0.999622545284467,
#  't_subj(Mismatch.Bad).1236': 1.0001715703009477,
#  't_subj(Mismatch.Good).1236': 1.000552227596763,
#  't_subj(Mismatch.Neutral).1236': 1.000143173740388,
#  't_subj(Mismatch.Bad).1237': 1.0013537415545946,
#  't_subj(Mismatch.Good).1237': 1.000941672450195,
#  't_subj(Mismatch.Neutral).1237': 0.9997344434674197,
#  'z_trans': 1.0007195092184364,
#  'z_std': 1.0004755003097339,
#  'z_subj_trans.1215': 0.9997590438390352,
#  'z_subj_trans.1216': 1.0027964809166563,
#  'z_subj_trans.1217': 1.0060717235255818,
#  'z_subj_trans.1218': 0.9995218147932587,
#  'z_subj_trans.1219': 1.0030351096225218,
#  'z_subj_trans.1220': 1.000437977752898,
#  'z_subj_trans.1221': 0.9998047767773431,
#  'z_subj_trans.1222': 1.000676902195472,
#  'z_subj_trans.1223': 0.9999258320371099,
#  'z_subj_trans.1224': 1.0005049139517914,
#  'z_subj_trans.1225': 0.9996854839154837,
#  'z_subj_trans.1226': 0.9998679388777675,
#  'z_subj_trans.1227': 0.9995705084398712,
#  'z_subj_trans.1228': 1.0002151939481712,
#  'z_subj_trans.1229': 1.0003902990454026,
#  'z_subj_trans.1230': 1.0000676936793353,
#  'z_subj_trans.1231': 1.00041844362906,
#  'z_subj_trans.1232': 1.0010790222424215,
#  'z_subj_trans.1233': 0.9996506554026666,
#  'z_subj_trans.1234': 1.0004274267160358,
#  'z_subj_trans.1235': 1.0003442163420266,
#  'z_subj_trans.1236': 1.0012248627137197,
#  'z_subj_trans.1237': 0.9998407886000803}

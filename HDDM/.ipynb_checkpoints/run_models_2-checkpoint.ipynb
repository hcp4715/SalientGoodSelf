# %%
import sys
import hddm, IPython
print('Notebook is running:', sys.executable)
from platform import python_version # further check your python version
print('The current HDDM version is', python_version())
print('The current HDDM version is', hddm.__version__) # 0.8.0
print('The current IPython version is', IPython.__version__)
# Out:
# Notebook is running: /home/hcp4715/miniconda3/envs/py_ddm/bin/python
# The current HDDM version is 3.7.7
# The current HDDM version is 0.8.0
# The current IPython version is 7.13.0
# /home/hcp4715/miniconda3/envs/py_ddm/lib/python3.7/site-packages/IPython/parallel.py:13: ShimWarning: The `IPython.parallel` package has been deprecated since IPython 4.0. You should import from ipyparallel instead.
#   "You should import from ipyparallel instead.", ShimWarning)

# %%
# %matplotlib inline

# Preparation
import os, hddm, time, csv
import kabuki

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from datetime import date
import random

# %%
# define a function to run model in parallel for experiments share the same design
def run_model_3a(id):
    import hddm
    
    exp_name = '3a'
    print('running models %i'%id, 'for for exp', exp_name)
    dbname = 'df' + exp_name + '_chain_vtaz_%i.db'%id   # define the database name, which uses pickle format
    mname  = 'df' + exp_name + '_chain__vtaz_%i'%id     # define the name for the model
    fname  = 'df' + exp_name + '.v.hddm_stim.csv'
    df = hddm.load_csv(fname)
    m = hddm.HDDMStimCoding(df, 
                            include='z', 
                            stim_col='stim', 
                            depends_on={'v':['match','val','id'], 't':['match','val','id'],'a':['match','val','id']},
                            split_param='v', 
                            drift_criterion=False,
                            p_outlier=0.05)
    m.find_starting_values()
    m.sample(10000, burn=5000, thin=5, dbname=dbname, db='pickle')
    m.save(mname) # save the model
    return m

def run_model_3b(id):
    import hddm
    
    exp_name = '3b'
    print('running models %i'%id, 'for for exp', exp_name)
    dbname = 'df' + exp_name + '_chain_vtaz_%i.db'%id   # define the database name, which uses pickle format
    mname  = 'df' + exp_name + '_chain__vtaz_%i'%id     # define the name for the model
    fname  = 'df' + exp_name + '.v.hddm_stim.csv'
    df = hddm.load_csv(fname)
    m = hddm.HDDMStimCoding(df, 
                            include='z', 
                            stim_col='stim', 
                            depends_on={'v':['match','val','id'], 't':['match','val','id'],'a':['match','val','id']},
                            split_param='v', 
                            drift_criterion=False,
                            p_outlier=.05)
    m.find_starting_values()
    m.sample(10000, burn=5000, thin=5, dbname=dbname, db='pickle')
    m.save(mname) # save the model
    return m

def run_model_4a(id):
    import hddm
    
    exp_name = '4a'
    print('running models %i'%id, 'for for exp', exp_name)
    dbname = 'df' + exp_name + '_chain_vtaz_%i.db'%id   # define the database name, which uses pickle format
    mname  = 'df' + exp_name + '_chain__vtaz_%i'%id     # define the name for the model
    fname  = 'df' + exp_name + '.v.hddm_stim.csv'
    df = hddm.load_csv(fname)
    m = hddm.HDDMStimCoding(df, 
                            include='z', 
                            stim_col='stim', 
                            depends_on={'v':['match','val','id'], 't':['match','val','id'],'a':['match','val','id']},
                            split_param='v', 
                            drift_criterion=False,
                            p_outlier=0.05)
    m.find_starting_values()
    m.sample(10000, burn=5000, thin=5, dbname=dbname, db='pickle')
    m.save(mname) # save the model
    return m

# define a function to run model in parallel for experiment 1b
def run_model_4b(id):
    import hddm
    
    exp_name = '4b'
    print('running models %i'%id, 'for for exp', exp_name)
    dbname = 'df' + exp_name + '_chain_vtaz_%i.db'%id   # define the database name, which uses pickle format
    mname  = 'df' + exp_name + '_chain__vtaz_%i'%id     # define the name for the model
    fname  = 'df' + exp_name + '.v.hddm_stim.csv'
    df = hddm.load_csv(fname)
    m = hddm.HDDMStimCoding(df, 
                            include='z', 
                            stim_col='stim', 
                            depends_on={'v':['match','val','id'], 't':['match','val','id'],'a':['match','val','id']},
                            split_param='v', 
                            drift_criterion=False,
                            p_outlier=0.05)
    m.find_starting_values()
    m.sample(10000, burn=5000, thin=5, dbname=dbname, db='pickle')
    m.save(mname) # save the model
    return m

def run_model_6b(id):
    import hddm
    
    exp_name = '6b'
    print('running models %i'%id, 'for for exp', exp_name)
    dbname = 'df' + exp_name + '_chain_vtaz_%i.db'%id   # define the database name, which uses pickle format
    mname  = 'df' + exp_name + '_chain__vtaz_%i'%id     # define the name for the model
    fname  = 'df' + exp_name + '_d1.v.hddm_stim.csv'
    df = hddm.load_csv(fname)
    m = hddm.HDDMStimCoding(df, 
                            include='z', 
                            stim_col='stim', 
                            depends_on={'v':['match','val','id'], 't':['match','val','id'],'a':['match','val','id']},
                            split_param='v', 
                            drift_criterion=False,
                            p_outlier=0.05)
    m.find_starting_values()
    m.sample(10000, burn=5000, thin=5, dbname=dbname, db='pickle')
    m.save(mname) # save the model
    return m

def run_model_7a(id):
    import hddm
    
    exp_name = '7a'
    print('running models %i'%id, 'for for exp', exp_name)
    dbname = 'df' + exp_name + '_chain_vtaz_%i.db'%id   # define the database name, which uses pickle format
    mname  = 'df' + exp_name + '_chain__vtaz_%i'%id     # define the name for the model
    fname  = 'df' + exp_name + '_m.v.hddm_stim.csv'
    df = hddm.load_csv(fname)
    m = hddm.HDDMStimCoding(df, 
                            include='z', 
                            stim_col='stim', 
                            depends_on={'v':['match','val','id'], 't':['match','val','id'],'a':['match','val','id']},
                            split_param='v', 
                            drift_criterion=False,
                            p_outlier=0.05)
    m.find_starting_values()
    m.sample(10000, burn=5000, thin=5, dbname=dbname, db='pickle')
    m.save(mname) # save the model
    return m

def run_model_7b(id):
    import hddm
    
    exp_name = '7b'
    print('running models %i'%id, 'for for exp', exp_name)
    dbname = 'df' + exp_name + '_chain_vtaz_%i.db'%id   # define the database name, which uses pickle format
    mname  = 'df' + exp_name + '_chain__vtaz_%i'%id     # define the name for the model
    fname  = 'df' + exp_name + '_m.v.hddm_stim.csv'
    df = hddm.load_csv(fname)
    m = hddm.HDDMStimCoding(df, 
                            include='z', 
                            stim_col='stim', 
                            depends_on={'v':['match','val','id'], 't':['match','val','id'],'a':['match','val','id']},
                            split_param='v', 
                            drift_criterion=False,
                            p_outlier=0.05)
    m.find_starting_values()
    m.sample(10000, burn=5000, thin=5, dbname=dbname, db='pickle')
    m.save(mname) # save the model
    return m

# %%
# exp_list = ['1a', '1b', '1c', '2', '6a']
#exp_list = ['3a', '3b', '4a', '4b', '6b', '7a', '7b']
exp_list = ['6b', '7a', '7b']
for mm in range(len(exp_list)): 
    
    if exp_list[mm] == '3a': 
        start_time = time.time()   # the start time of the processing#
        print('\nrun model for exp', exp_list[mm])
        from ipyparallel import Client
        rc = Client()
        jobs = rc[0:4].map(run_model_3a, range(4)) # 4 is the number of chains
        df_models = jobs.get()
        print("Running 4 chains for exp", exp_list[mm], "used: %f seconds." % (time.time() - start_time))
        
    elif exp_list[mm] == '3b':
        start_time = time.time()   # the start time of the processing#
        print('\nrun model for exp', exp_list[mm])
        from ipyparallel import Client
        rc = Client()
        jobs = rc[0:4].map(run_model_3b, range(4)) # 4 is the number of chains
        df_models = jobs.get()
        print("Running 4 chains for exp", exp_list[mm], "used: %f seconds." % (time.time() - start_time))
        
    elif exp_list[mm] == '4a':
        start_time = time.time()   # the start time of the processing#
        print('\nrun model for exp', exp_list[mm])
        from ipyparallel import Client
        rc = Client()
        jobs = rc[0:4].map(run_model_4a, range(4)) # 4 is the number of chains
        df_models = jobs.get()
        print("Running 4 chains for exp", exp_list[mm], "used: %f seconds." % (time.time() - start_time))
    elif exp_list[mm] == '4b':
        start_time = time.time()   # the start time of the processing#
        print('\nrun model for exp', exp_list[mm])
        from ipyparallel import Client
        rc = Client()
        jobs = rc[0:4].map(run_model_4b, range(4)) # 4 is the number of chains
        df_models = jobs.get()
        print("Running 4 chains for exp", exp_list[mm], "used: %f seconds." % (time.time() - start_time))
        
    elif exp_list[mm] == '6b':
        start_time = time.time()   # the start time of the processing#
        print('\nrun model for exp', exp_list[mm])
        from ipyparallel import Client
        rc = Client()
        jobs = rc[0:4].map(run_model_6b, range(4)) # 4 is the number of chains
        df_models = jobs.get()
        print("Running 4 chains for exp", exp_list[mm], "used: %f seconds." % (time.time() - start_time))

    elif exp_list[mm] == '7a':
        start_time = time.time()   # the start time of the processing#
        print('\nrun model for exp', exp_list[mm])
        from ipyparallel import Client
        rc = Client()
        jobs = rc[0:4].map(run_model_7a, range(4)) # 4 is the number of chains
        df_models = jobs.get()
        print("Running 4 chains for exp", exp_list[mm], "used: %f seconds." % (time.time() - start_time))
        
    elif exp_list[mm] == '7b':
        start_time = time.time()   # the start time of the processing#
        print('\nrun model for exp', exp_list[mm])
        from ipyparallel import Client
        rc = Client()
        jobs = rc[0:4].map(run_model_7b, range(4)) # 4 is the number of chains
        df_models = jobs.get()
        print("Running 4 chains for exp", exp_list[mm], "used: %f seconds." % (time.time() - start_time))
# Out:
# run model for exp 6b
# Running 4 chains for exp 6b used: 13562.753697 seconds.
#
# run model for exp 7a
# Running 4 chains for exp 7a used: 11661.717781 seconds.
#
# run model for exp 7b
# Running 4 chains for exp 7b used: 16684.631820 seconds.
